# %% [markdown]
# ## Utrecht University - Network Science
#
# ### Community Detecion in the European Football Transfer Market

# %% [markdown]
# The data is obtained from the following repository: https://github.com/ewenme/transfers/tree/master. The data is provided as csv files and it is freely available to actively encourage new research and analysis at all levels in Football Analytics. The structure of the data is the following:
#
# > English Premier League (premier-league.csv)
#
# > English Championship (championship.csv)
#
# > French Ligue 1 (ligue-1.csv)
#
# >German 1.Bundesliga (1-bundesliga.csv)
#
# >Italian Serie A (serie-a.csv)
#
# >Spanish La Liga (primera-division.csv)
#
# >Portugese Liga NOS (liga-nos.csv)
#
# >Dutch Eredivisie (eredivisie.csv)
#
# >Russian Premier Liga (premier-liga.csv)
#
# Each dataset has the following common variables:
#
#
#
#
# <div style="display: flex; justify-content: center; align-items: flex-start; gap: 20px; height: 350px;">
#   <div style="height: 100%;">
#     <img src="variables_transfer_data.jpg" style="height: 100%; object-fit: contain;">

# %% [markdown]
# ### 1. Data Loading and Exploration

# %%
import pandas as pd
import numpy as np


path = "premier-league.csv"

dataframe = pd.read_csv(path)

dataframe[dataframe['player_name'] == 'Gonçalo Guedes']
# Out:
#                      club_name     player_name   age        position  \
# 23468  Wolverhampton Wanderers  Gonçalo Guedes  25.0     Left Winger
# 23673  Wolverhampton Wanderers  Gonçalo Guedes  26.0  Second Striker
#
#       club_involved_name            fee transfer_movement transfer_period  \
# 23468           Valencia        €32.60m                in          Summer
# 23673            Benfica  loan transfer               out          Winter
#
#        fee_cleaned     league_name  year     season  country
# 23468         32.6  Premier League  2022  2022/2023  England
# 23673          NaN  Premier League  2022  2022/2023  England

# %%
path2 = "primera-division.csv"

dataframe2 = pd.read_csv(path2)

dataframe2[dataframe2['player_name'] == 'Gonçalo Guedes']
# Out:
#          club_name     player_name   age     position club_involved_name  \
# 13229  Valencia CF  Gonçalo Guedes  20.0  Left Winger           Paris SG
# 14136  Valencia CF  Gonçalo Guedes  21.0  Left Winger           Paris SG
# 14166  Valencia CF  Gonçalo Guedes  21.0  Left Winger           Paris SG
# 16872  Valencia CF  Gonçalo Guedes  25.0  Left Winger             Wolves
#
#                            fee transfer_movement transfer_period  fee_cleaned  \
# 13229            loan transfer                in          Summer          NaN
# 14136                  €40.00m                in          Summer         40.0
# 14166  End of loanJun 30, 2018               out          Summer          NaN
# 16872                  €32.60m               out          Summer         32.6
#
#             league_name  year     season country
# 13229  Primera Division  2017  2017/2018   Spain
# 14136  Primera Division  2018  2018/2019   Spain
# 14166  Primera Division  2018  2018/2019   Spain
# 16872  Primera Division  2022  2022/2023   Spain

# %%
path3 = "liga-nos.csv"

dataframe3 = pd.read_csv(path3)

dataframe3[dataframe3['player_name'] == 'Gonçalo Guedes']
# Out:
#         club_name     player_name   age        position club_involved_name  \
# 14011  SL Benfica  Gonçalo Guedes  18.0     Left Winger          Benfica B
# 15996  SL Benfica  Gonçalo Guedes  20.0     Left Winger           Paris SG
# 21572  SL Benfica  Gonçalo Guedes  26.0  Second Striker             Wolves
#
#                  fee transfer_movement transfer_period  fee_cleaned  \
# 14011              -                in          Winter          NaN
# 15996        €30.00m               out          Winter         30.0
# 21572  loan transfer                in          Winter          NaN
#
#       league_name  year     season   country
# 14011    Liga Nos  2014  2014/2015  Portugal
# 15996    Liga Nos  2016  2016/2017  Portugal
# 21572    Liga Nos  2022  2022/2023  Portugal

# %% [markdown]
# By exploring the dataset, we can see how the transfers are recorded in the data.
#
# Basically every transfer movement is recorded for each club in each league.
# > When the _transfer_movement_ variable has "in" value, it means that the player has signed for the club that figures in the _club_name_ field.
#
# > When the _transfer_movement_ variable has "out" value, it means that the player has signed for the club that figures in the _club_involved_name_ field.
#
# Also, its important to notice that the same transfer, will be recorded twice in the data, as it will figure both in the dataset for the buying club, and in the dataset for the selling club. Above we can see an example of the transfer involving Valencia CF and Wolverhampton Wonderers for the player Gonçalo Guedes.
# The instance is registered both in the dataset for the spanish la liga transfers and english premier league transfers.
#
# Overall, the transfers produced between clubs will be accounted twice, but that does not require any treatment as it will be the same for all transfers with all the clubs involved in the data, so at the end the duplicity will have no effect or bias, as it will be present throughout all the connections between clubs. An alternative way to solve this duplicity is simply filtering all the registers from the final unified dataset, that belong to _transfer_movement_ "in".
#
# Another important point is to notice the Data-Quality of the club names present in the data. We can see how the same club (Wolverhampton Wonderers), has different naming formats. While in the premier league dataset is written as "Wolverhampton Wonderers", in the spanish dataset is written as "Wolves". This is an issue we have to solve before hand. We will normalize the namings of all the different clubs present in all the datasets.

# %%
# List of all the file paths we have as data

path_english_premier_league = "premier-league.csv"
path_english_championship = "championship.csv"
path_french_ligue1 = "ligue-1.csv"
path_german_bundesliga = "1-bundesliga.csv"
path_italian_serieA = "serie-a.csv"
path_spanish_laliga = "primera-division.csv"
path_portugese_ligaNOS = "liga-nos.csv"
path_dutch_eredivisie = "eredivisie.csv"
path_russian_premier_liga = "premier-liga.csv"

# %%
df_english_premier_league = pd.read_csv(path_english_premier_league)
df_english_championship = pd.read_csv(path_english_championship)
df_french_ligue1 = pd.read_csv(path_french_ligue1)
df_german_bundesliga = pd.read_csv(path_german_bundesliga)
df_italian_serieA = pd.read_csv(path_italian_serieA)
df_spanish_laliga = pd.read_csv(path_spanish_laliga)
df_portugese_ligaNOS = pd.read_csv(path_portugese_ligaNOS)
df_dutch_eredivisie = pd.read_csv(path_dutch_eredivisie)
df_russian_premier_liga = pd.read_csv(path_russian_premier_liga)

# %%
# Collecting all the different club names present in the data

# Storing all dataframes in a list
dfs = [
    df_english_premier_league,
    df_english_championship,
    df_french_ligue1,
    df_german_bundesliga,
    df_italian_serieA,
    df_spanish_laliga,
    df_portugese_ligaNOS,
    df_dutch_eredivisie,
    df_russian_premier_liga
]

# Collecting all unique club names from both columns
clubs = set()

for df in dfs:
    clubs.update(df["club_name"].dropna().unique())
    clubs.update(df["club_involved_name"].dropna().unique())

# Sorting alphabetically for inspection
clubs = sorted(clubs)

print(f"Total unique club names: {len(clubs)}")
# Out:
# Total unique club names: 6386

# %%
# clubs

# %%
# We filter out all the youth system teams for each club (check how many youth system teams we have)

import re

# Pattern for youth teams: U16, U17, U18, U19, U20, U21
u_team_pattern = r"\bU(16|17|18|19|20|21)\b"

# Clubs that match this pattern
u_teams = [club for club in clubs if re.search(u_team_pattern, str(club), flags=re.IGNORECASE)]

print(f"Number of U16-U21 club names: {len(u_teams)}")
u_teams[:20]
# Out:
# Number of U16-U21 club names: 526
# ['1.FC Köln U19',
#  'ADO U19',
#  'ADO U21',
#  'AJ Auxerre U19',
#  'APC U20',
#  'AS Cannes U19',
#  'AS Nancy U19',
#  'AZ Alkmaar U17',
#  'AZ Alkmaar U19',
#  'AZ Alkmaar U21',
#  'AZ U18',
#  'Aachen U19',
#  'Académica U19',
#  'Ajax U18',
#  'Ajax U19',
#  'Ajax U21',
#  'Alavés U19',
#  'Albacete U19',
#  'Almere City U21',
#  'Alverca U19']

# %%
# We will still use the transactions between clubs even if they are for the youth systems
clubs_without_u_teams = clubs

# In case we would like to create a new list without those clubs

# [
#     club for club in clubs
#     if not re.search(u_team_pattern, str(club), flags=re.IGNORECASE)
# ]

# print(f"Original clubs: {len(clubs)}")
# print(f"After removing U16-U21 clubs: {len(clubs_without_u_teams)}")
# print(f"Removed: {len(clubs) - len(clubs_without_u_teams)}")

# %%
# Applying some data engineering techniques to solve data-quality problems regarding different namings of a same club

# If needed:
# !pip install rapidfuzz

from rapidfuzz import process, fuzz

clubs_clean_base = clubs_without_u_teams
# Out:
# Requirement already satisfied: rapidfuzz in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (3.14.5)
# WARNING: You are using pip version 21.2.3; however, version 26.1.1 is available.
# You should consider upgrading via the 'C:\Users\lenovo\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# Applying the functionallity of the library to extract fuzzy matchings from a set, with a certain word
process.extract(
    "Wolves",
    clubs_clean_base,
    scorer=fuzz.WRatio,
    limit=15
)
# Out:
# [('Wolves', 100.0, 6220),
#  ('Wolves FC', 90.0, 6221),
#  ('Wolves Res.', 90.0, 6222),
#  ('Wolves U18', 90.0, 6223),
#  ('Wolves U21', 90.0, 6224),
#  ('Wolves U23', 90.0, 6225),
#  ('Wolverhampton Wanderers', 81.81818181818181, 6219),
#  ('Wolvega', 76.92307692307692, 6218),
#  ('Ilves', 72.72727272727273, 2847),
#  ('Bento Gonçalves', 72.0, 798),
#  ('CD Mostoles', 72.0, 1092),
#  ('Silves FC', 68.4, 5109),
#  ('Novese', 66.66666666666667, 3915),
#  ('Albion Rovers', 65.45454545454547, 364),
#  ('Barton Rovers', 65.45454545454547, 741)]

# %%
# To search different duplicated candidates in fast and automated way
def find_similar_clubs(club_name, limit=15):
    return process.extract(
        club_name,
        clubs_clean_base,
        scorer=fuzz.WRatio,
        limit=limit
    )

# %%
find_similar_clubs("Man Utd")
# Out:
# [('Man Utd', 100.0, 3517),
#  ('Man Utd Res.', 90.0, 3518),
#  ('Man Utd U18', 90.0, 3519),
#  ('Man Utd U21', 90.0, 3520),
#  ('Man Utd U23', 90.0, 3521),
#  ('Hastings Utd', 85.5, 2726),
#  ('Inglewood Utd', 85.5, 2862),
#  ('JEF Utd Ichihara', 85.5, 2936),
#  ('Man City Res.', 85.5, 3513),
#  ('Man City U18', 85.5, 3514),
#  ('Man City U21', 85.5, 3515),
#  ('Man City U23', 85.5, 3516),
#  ('Oxford Utd U18', 85.5, 4059),
#  ('Sheff Utd U18', 85.5, 5068),
#  ('Sheff Utd U21', 85.5, 5069)]

# %%
find_similar_clubs("Manchester United")
# Out:
# [('Manchester United', 100.0, 3525),
#  ('Akwa United', 85.5, 285),
#  ('Ayr United', 85.5, 640),
#  ('D.C. United', 85.5, 1549),
#  ('FC United', 85.5, 2145),
#  ('Home United', 85.5, 2783),
#  ('Hyde United', 85.5, 2815),
#  ('Jeju United', 85.5, 2961),
#  ('NF United', 85.5, 3758),
#  ('SF United', 85.5, 4765),
#  ('WP United', 85.5, 6124),
#  ('Colchester United', 82.35294117647058, 1443),
#  ('Manchester City', 81.25, 3524),
#  ('Chester', 77.14285714285715, 1364),
#  ('Jasper United', 73.33333333333334, 2956)]

# %%
find_similar_clubs("Manchester City")
# Out:
# [('Manchester City', 100.0, 3524),
#  ('Bath City', 85.5, 751),
#  ('Cork City', 85.5, 1480),
#  ('Derry City', 85.5, 1645),
#  ('Elm City', 85.5, 1840),
#  ('GZ City', 85.5, 2455),
#  ('Hull City', 85.5, 2804),
#  ('Man City', 85.5, 3512),
#  ('Newry City', 85.5, 3865),
#  ('Pune City', 85.5, 4347),
#  ('Stoke City', 85.5, 5342),
#  ('York City', 85.5, 6262),
#  ('Lancaster City', 82.75862068965517, 3220),
#  ('Chester City', 81.4814814814815, 1365),
#  ('Manchester United', 81.25, 3525)]

# %%
find_similar_clubs("Man City")
# Out:
# [('Man City', 100.0, 3512),
#  ('Man City Res.', 90.0, 3513),
#  ('Man City U18', 90.0, 3514),
#  ('Man City U21', 90.0, 3515),
#  ('Man City U23', 90.0, 3516),
#  ('Adelaide City', 85.5, 244),
#  ('Almere City Am.', 85.5, 401),
#  ('Almere City U21', 85.5, 402),
#  ('Auckland City', 85.5, 609),
#  ('Bankstown City', 85.5, 711),
#  ('Birmingham City', 85.5, 826),
#  ('Bradford City', 85.5, 929),
#  ('Bristol City', 85.5, 975),
#  ('Cambridge City', 85.5, 1200),
#  ('Cape Town City', 85.5, 1221)]

# %%
find_similar_clubs("Real Madrid")
# Out:
# [('Real Madrid', 100.0, 4520),
#  ('Real Madrid B', 95.0, 4521),
#  ('Real Madrid C', 95.0, 4522),
#  ('Real Madrid U19', 95.0, 4523),
#  ('Atlético de Madrid', 85.5, 596),
#  ('Real Betis Balompié', 85.5, 4515),
#  ('Real SC', 85.5, 4528),
#  ('Real Valladolid CF', 85.5, 4536),
#  ('Real Murcia', 72.72727272727273, 4524),
#  ('Real Valladolid', 69.23076923076923, 4535),
#  ('Bari', 67.5, 724),
#  ('Atl. Madrid B', 67.05882352941177, 571),
#  ('Atl. Madrid C', 67.05882352941177, 572),
#  ('Atl. Madrid U19', 67.05882352941177, 573),
#  ('Atlético Madrid', 67.05882352941177, 595)]

# %%
find_similar_clubs("Dortmund")
# Out:
# [('B. Dortmund II', 90.0, 644),
#  ('B. Dortmund U17', 90.0, 645),
#  ('B. Dortmund U19', 90.0, 646),
#  ('Bor. Dortmund', 90.0, 888),
#  ('Borussia Dortmund', 90.0, 901),
#  ('Dro', 72.0, 1729),
#  ('Fortuna du Mfou', 67.5, 2371),
#  ('Fortuna Düsseldorf', 64.28571428571429, 2368),
#  ('Fortuna Sittard', 64.28571428571429, 2369),
#  ('Portland', 62.5, 4287),
#  ('SC Fortuna Köln', 61.07142857142858, 4707),
#  ('Brumunddal Fotball', 60.00000000000001, 988),
#  ('Dordrecht U19', 60.00000000000001, 1714),
#  ('Dordrecht U21', 60.00000000000001, 1715),
#  ("Dordrecht'90", 60.00000000000001, 1716)]

# %%
find_similar_clubs("Bayern")
# Out:
# [('Bayern Munich', 90.0, 758),
#  ('FC Bayern II', 90.0, 1962),
#  ('FC Bayern U19', 90.0, 1963),
#  ('Bayer 04 Leverkusen', 81.81818181818181, 756),
#  ('Bayer 05 Uerdingen', 81.81818181818181, 757),
#  ('Ban', 72.0, 702),
#  ('Barnsley FC', 72.0, 730),
#  ('Barnsley U18', 72.0, 731),
#  ('Barnsley U23', 72.0, 732),
#  ('Bra', 72.0, 925),
#  ('Dinamo Barnaul', 68.4, 1676),
#  ('SDV Barneveld', 68.4, 4758),
#  ('SpVgg Bayreuth', 68.4, 5197),
#  ('São Bernardo-SP', 68.4, 5405),
#  ('Ballymena', 66.66666666666667, 696)]

# %%
find_similar_clubs("Juventus")
# Out:
# [('Juventus', 100.0, 2988),
#  ('CA Juventus', 95.0, 1043),
#  ('Juventus FC', 95.0, 2990),
#  ('Juventus SA', 95.0, 2991),
#  ('Fortis Juventus', 90.0, 2367),
#  ('GE Juventus-SC', 90.0, 2439),
#  ('Juventus Buk.', 90.0, 2989),
#  ('Juventus U19', 90.0, 2992),
#  ('Juventus U23', 90.0, 2993),
#  ('SC YF Juventus', 90.0, 4741),
#  ('Juventud', 87.5, 2985),
#  ('Juventus-AC', 84.21052631578947, 2994),
#  ('Juventude U20', 84.0, 2987),
#  ('Juventude', 82.35294117647058, 2986),
#  ('EC Juventude B', 78.75, 1784)]

# %% [markdown]
# ### 2. Data Engineering

# %%
# Concating all the different dataframes we have to get an unified df, but adding the identyfier feature league

league_dfs = {
    "english_premier_league": df_english_premier_league,
    "english_championship": df_english_championship,
    "french_ligue1": df_french_ligue1,
    "german_bundesliga": df_german_bundesliga,
    "italian_serieA": df_italian_serieA,
    "spanish_laliga": df_spanish_laliga,
    "portugese_ligaNOS": df_portugese_ligaNOS,
    "dutch_eredivisie": df_dutch_eredivisie,
    "russian_premier_liga": df_russian_premier_liga,
}

all_transfers = pd.concat(
    [
        df.assign(source_league=league_name)
        for league_name, df in league_dfs.items()
    ],
    ignore_index=True
)

all_transfers.shape
# Out:
# (177412, 14)

# %%
all_transfers.head()
# Out:
#           club_name       player_name   age     position club_involved_name  \
# 0  Middlesbrough FC      Tommy Wright  26.0  Left Winger          Leicester
# 1  Middlesbrough FC  Jonathan Gittens  28.0      defence        Southampton
# 2  Middlesbrough FC      Chris Morris  28.0   Right-Back             Celtic
# 3  Middlesbrough FC       Ben Roberts  17.0   Goalkeeper           Boro U18
# 4  Middlesbrough FC         Andy Todd  17.0  Centre-Back           Boro U18
#
#        fee transfer_movement transfer_period  fee_cleaned     league_name  \
# 0  €910Th.                in          Summer         0.91  Premier League
# 1  €250Th.                in          Summer         0.25  Premier League
# 2        ?                in          Summer          NaN  Premier League
# 3        -                in          Summer          NaN  Premier League
# 4        -                in          Summer          NaN  Premier League
#
#    year     season  country           source_league
# 0  1992  1992/1993  England  english_premier_league
# 1  1992  1992/1993  England  english_premier_league
# 2  1992  1992/1993  England  english_premier_league
# 3  1992  1992/1993  England  english_premier_league
# 4  1992  1992/1993  England  english_premier_league

# %%
# Function to delete the suffixes U16, U17, U18, U20, U21 that refer to the youth system teams of a same club

import re

# Defining the function to remove academy / reserve suffixes
def remove_academy_suffix(name):
    if pd.isna(name):
        return name
    
    name = str(name).strip()
    
    # Remove U16, U-16, U 16, U18s, etc.
    name = re.sub(
        r"[\s\-]*(U\s*-?\s*(16|17|18|19|20|21|23)s?)\b",
        "",
        name,
        flags=re.IGNORECASE
    )
    
    # Remove Under 16, Under-18, Under 21, etc.
    name = re.sub(
        r"[\s\-]*(Under\s*-?\s*(16|17|18|19|20|21|23))\b",
        "",
        name,
        flags=re.IGNORECASE
    )
    
    # Remove Sub-23, Sub 23, Sub23, etc.
    name = re.sub(
        r"[\s\-]*(Sub\s*-?\s*(16|17|18|19|20|21|23))\b",
        "",
        name,
        flags=re.IGNORECASE
    )
    
    # Remove trailing " B"
    name = re.sub(
        r"\s+B$",
        "",
        name,
        flags=re.IGNORECASE
    )
    
    # Remove trailing " C"
    name = re.sub(
        r"\s+C$",
        "",
        name,
        flags=re.IGNORECASE
    )
    
    
    # Remove trailing " II"
    name = re.sub(
        r"\s+II$",
        "",
        name,
        flags=re.IGNORECASE
    )
    
    # Clean extra spaces
    name = re.sub(r"\s+", " ", name)
    name = re.sub(r"[\s\-]+$", "", name)
    
    return name.strip()


# Applying the function to the 2 columns of our dataframe that apply
all_transfers["club_name_clean"] = all_transfers["club_name"].apply(remove_academy_suffix)
all_transfers["club_involved_name_clean"] = all_transfers["club_involved_name"].apply(remove_academy_suffix)

# %%
# Checking the reduction
raw_clubs = set(all_transfers["club_name"].dropna()).union(
    set(all_transfers["club_involved_name"].dropna())
)

clean_clubs = set(all_transfers["club_name_clean"].dropna()).union(
    set(all_transfers["club_involved_name_clean"].dropna())
)

print("Raw unique clubs:", len(raw_clubs))
print("After removing academy suffixes:", len(clean_clubs))
print("Reduced by:", len(raw_clubs) - len(clean_clubs))
# Out:
# Raw unique clubs: 6386
# After removing academy suffixes: 5797
# Reduced by: 589

# %%
# Remove rows where the other club is missing
all_transfers = all_transfers.dropna(subset=["club_name", "club_involved_name"])
    
# Remove self-loops (club trading with itself — data errors)
all_transfers = all_transfers[all_transfers["club_name_clean"] != all_transfers["club_involved_name_clean"]]

# %%
# Manually defining the fuzzy mapping names to improve our dataset quality

club_name_mapping = {

    # Wolverhampton
    "Wolves": "Wolverhampton Wanderers",
    "Wolves FC": "Wolverhampton Wanderers",
    "Wolves Res.": "Wolverhampton Wanderers",
    "Wolves U18": "Wolverhampton Wanderers",
    "Wolves U21": "Wolverhampton Wanderers",
    "Wolves U23": "Wolverhampton Wanderers",

    # Manchester City
    "Man City": "Manchester City",
    "Man City Res.": "Manchester City",
    "Man City U18": "Manchester City",
    "Man City U21": "Manchester City",
    "Man City U23": "Manchester City",
    
    # Manchester United
    "Man Utd": "Manchester United",
    "Man Utd Res": "Manchester United",
    "Man Utd U18": "Manchester United",
    "Man Utd U21": "Manchester United",
    "Man Utd U23": "Manchester United",
    
    # Real Madrid
    "Real Madrid B": "Real Madrid",
    "Real Madrid C": "Real Madrid",
    "Real Madrid U19": "Real Madrid",
    "RM Castilla": "Real Madrid",
    "Real Madrid": "Real Madrid",
    
    # Borussia Dortmund
    "B. Dortmund II": "Borussia Dortmund",
    "B. Dortmund U17": "Borussia Dortmund",
    "B. Dortmund U19": "Borussia Dortmund",
    "B. Dortmund": "Borussia Dortmund",
    "Bor. Dortmund": "Borussia Dortmund",
    
    # Bayern Munchen
    "Bayern Munich": "Bayern Munich",
    "FC Bayern II": "Bayern Munich",
    "FC Bayern U19": "Bayern Munich",
    "FC Bayern": "Bayern Munich",

    # Juventus
    "Juventus FC": "Juventus",
    "Juventus U19": "Juventus",
    "Juventus U23": "Juventus",
    "Juventud": "Juventus",
    "Juventus": "Juventus",
    
    # FC Barcelona
    "FCBarcelona": "FC Barcelona",
    "Barcelona": "FC Barcelona",
    "Barcelona B": "FC Barcelona",
    "Barcelona C": "FC Barcelona",
    "Barça Atlètic": "FC Barcelona",
    "Barça U19": "FC Barcelona",
    "Barça": "FC Barcelona",
    
    # Leicester
    "Leicester City": "Leicester City",
    "Leicester": "Leicester City",
    "Leicester U18": "Leicester City",
    "Leicester U21": "Leicester City",
    "Leicester U23": "Leicester City",
    "Leicester Res": "Leicester City",
    
    # Southampton
    "Southampton FC": "Southampton FC",
    "Southampton": "Southampton FC",
    "Southampton Aca": "Southampton FC",
    "Southampton B": "Southampton FC",
    "Southampton Res.": "Southampton FC",
    "Southampton U18": "Southampton FC",
    "Southampton U21": "Southampton FC",
    "Southampton U23": "Southampton FC",
    
    # FC Inter
    "FC Internazionale": "FC Internazionale",
    "Inter": "FC Internazionale",
    "Inter B": "FC Internazionale",
    "FC Inter": "FC Internazionale",
    "Inter U17": "FC Internazionale",
    "Inter U19": "FC Internazionale",
    "Inter U20": "FC Internazionale",
    "Inter Milan": "FC Internazionale",
    
    # Liverpool FC
    "Liverpool FC": "Liverpool FC",
    "Liverpool": "Liverpool FC",
    
    # Villarreal FC
    "Villarreal FC": "Villarreal FC",
    "Villarreal": "Villarreal FC",
    "Villarreal CF": "Villarreal FC",
    "Villarreal Yth.": "Villarreal FC",
    "Villarreal U19": "Villarreal FC",
    "FC Villarreal C": "Villarreal FC",
    "FC Villarreal": "Villarreal FC",
    "Villarreal CF B": "Villarreal FC",
    "Vila Real": "Villarreal FC",

    # Chelsea FC
    "Chelsea FC": "Chelsea FC",
    "Chelsea": "Chelsea FC",
    
    # CA Osasuna
    "CA Osasuna": "CA Osasuna",
    "Osasuna": "CA Osasuna",
    "CA Osasuna Prom": "CA Osasuna",
    
    # Burnley FC
    "Burnley": "Burnley FC",
    "Burnley FC": "Burnley FC",
    
    # Levante UD
    "Levante": "Levante UD",
    "Levante UD": "Levante UD",
    
    # Valencia CF
    "Valencia": "Valencia CF",
    "Valencia CF": "Valencia CF",
    
    # AC Milan
    "AC Milan": "AC Milan",
    "Milan": "AC Milan",
    "AC Milan Youth": "AC Milan",
    "Milan AC": "AC Milan",
    "Milan U19": "AC Milan",
    
    # AC Fiorentina
    "AC Fiorentina": "AC Fiorentina",
    "Fiorentina": "AC Fiorentina",
    
    # Atletico de Madrid
    "Atlético de Madrid": "Atletico de Madrid",
    "Atl. Madrid B": "Atletico de Madrid",
    "Atlético Madrid": "Atletico de Madrid",
    "Atl. Madrid U19": "Atletico de Madrid",
    "Atl. Madrid": "Atletico de Madrid",
    
    # Athletic Bilbao
    "Athletic Bilbao": "Athletic de Bilbao",
    "Bilbao Athletic": "Athletic de Bilbao",
    "Bilbao U19": "Athletic de Bilbao",
    
    # Real Betis
    "Real Betis": "Real Betis",
    "Real Betis Balompié": "Real Betis",
    "Betis B": "Real Betis",
    "Betis Deportivo": "Real Betis",
    "Betis": "Real Betis",
    
    # RCD Espanyol
    "RCD Espanyol": "RCD Espanyol",
    "RCD Espanyol B": "RCD Espanyol",
    "RCD Espanyol Barcelona": "RCD Espanyol",
    "Espanyol": "RCD Espanyol",
    
    # Racing Santander
    "Racing Santander": "Racing Santander",
    "Racing": "Racing Santander",
    
    # Real Valladolid
    "Real Valladolid": "Real Valladolid CF",
    "Real Valladolid CF": "Real Valladolid CF",
    "Valladolid": "Real Valladolid CF",
    "R. Valladolid B": "Real Valladolid CF",
    "R. Valladolid": "Real Valladolid CF",
    
    # AS Roma
    "Roma": "AS Roma",
    "AS Roma": "AS Roma",
    
    # Ajax Amsterdam
    "Ajax": "Ajax Amsterdam",
    "Ajax Amsterdam": "Ajax Amsterdam",
    "Ajax Cape Town": "Ajax Amsterdam",
    "Ajax Amateurs": "Ajax Amsterdam",
    
    # Arsenal FC
    "Arsenal": "Arsenal FC",
    "Arsenal FC II": "Arsenal FC",
    "Arsenal FC": "Arsenal FC",
    
    # Girona
    "Girona": "Girona FC",
    "Girona FC": "Girona FC",
    "Girona FC B": "Girona FC",
    
    # Sparta
    "Spartak": "Sparta",
    
    # Stade Rennais
    "Rennes": "Stade Rennais"   
    
     
# We need to keep adding data-quality issues regarding club namings here!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!  
    
}

# %%
# Applying the mappings to our dataframe
all_transfers["club_name_clean"] = all_transfers["club_name_clean"].replace(club_name_mapping)
all_transfers["club_involved_name_clean"] = all_transfers["club_involved_name_clean"].replace(club_name_mapping)

# Remove self-loops again (club trading with itself — data errors)
all_transfers = all_transfers[all_transfers["club_name_clean"] != all_transfers["club_involved_name_clean"]]

# %%
# Final check of how many different unique clubs we have in the dataset (number of nodes our network will have)
final_clubs = set(all_transfers["club_name_clean"].dropna()).union(
    set(all_transfers["club_involved_name_clean"].dropna())
)

print("After manual mapping:", len(final_clubs))
# Out:
# After manual mapping: 5743

# %%
all_transfers.head()
# Out:
#           club_name       player_name   age     position club_involved_name  \
# 0  Middlesbrough FC      Tommy Wright  26.0  Left Winger          Leicester
# 1  Middlesbrough FC  Jonathan Gittens  28.0      defence        Southampton
# 2  Middlesbrough FC      Chris Morris  28.0   Right-Back             Celtic
# 3  Middlesbrough FC       Ben Roberts  17.0   Goalkeeper           Boro U18
# 4  Middlesbrough FC         Andy Todd  17.0  Centre-Back           Boro U18
#
#        fee transfer_movement transfer_period  fee_cleaned     league_name  \
# 0  €910Th.                in          Summer         0.91  Premier League
# 1  €250Th.                in          Summer         0.25  Premier League
# 2        ?                in          Summer          NaN  Premier League
# 3        -                in          Summer          NaN  Premier League
# 4        -                in          Summer          NaN  Premier League
#
#    year     season  country           source_league   club_name_clean  \
# 0  1992  1992/1993  England  english_premier_league  Middlesbrough FC
# 1  1992  1992/1993  England  english_premier_league  Middlesbrough FC
# 2  1992  1992/1993  England  english_premier_league  Middlesbrough FC
# 3  1992  1992/1993  England  english_premier_league  Middlesbrough FC
# 4  1992  1992/1993  England  english_premier_league  Middlesbrough FC
#
#   club_involved_name_clean
# 0           Leicester City
# 1           Southampton FC
# 2                   Celtic
# 3                     Boro
# 4                     Boro

# %%
# Now we can just deduplicate the transfer instances, as they are duplicated from the point of view of each 2 clubs
# involved in each transfer. But by filtering by the transfer_movement feature, we can take only one!

# Checking the amount of registers of each type (they do not necessarily have to match, because clubs from outside
# the considered leagues can also be involved both in providing or in buying players, but we do not care about those clubs)
all_transfers['transfer_movement'].value_counts()
# Out:
# transfer_movement
# out    92217
# in     82027
# Name: count, dtype: int64

# %%
# Filtering our dataframe by only those "in" registers
transfer_df = all_transfers[
    all_transfers["transfer_movement"].str.lower() == "in"
].copy()

# Renaming columns to be cleaner
transfer_df = transfer_df.rename(columns={
    "club_involved_name_clean": "source_club",
    "club_name_clean": "target_club"
})

# %% [markdown]
# Further data-engineering process to fix the data-quality club naming issues.

# %%
# Applying again another check to avoid club naming data-quality issues

from rapidfuzz import fuzz
import pandas as pd
from itertools import combinations

# All unique club names currently appearing in transfers
all_clubs = sorted(
    set(transfer_df["source_club"].dropna())
    .union(set(transfer_df["target_club"].dropna()))
)

# Find all pairs of club names with similarity >= threshold
threshold = 89

similar_pairs = []

for club1, club2 in combinations(all_clubs, 2):
    score = fuzz.WRatio(club1, club2)
    
    if score >= threshold:
        similar_pairs.append({
            "club_1": club1,
            "club_2": club2,
            "similarity": score
        })

similar_pairs_df = (
    pd.DataFrame(similar_pairs)
    .sort_values("similarity", ascending=False)
    .reset_index(drop=True)
)

similar_pairs_df.head(100)

similar_pairs_df.to_csv("similar_club_name_candidates.csv", index=False)

# %%
# With this generated csv with all the mappings, we can use it to fix the remaining club names!

# Load reviewed mappings
mapping_df = pd.read_csv("similar_club_name_candidates.csv")

# Keep only needed columns and remove empty rows
mapping_df = mapping_df[["club_1", "club_2"]].dropna().copy()

# Dictionary: wrong/variant name -> canonical name
csv_mapping = dict(zip(mapping_df["club_2"], mapping_df["club_1"]))

print("Mappings loaded:", len(csv_mapping))
list(csv_mapping.items())[:20]
# Out:
# Mappings loaded: 834
# [('Shinnik Yaroslavl', 'Shinnik'),
#  ('ACF Fiorentina', 'AC Fiorentina'),
#  ('Hibernians FC', 'Hibernian FC'),
#  ('GFCO Ajaccio', 'GFC Ajaccio'),
#  ('Al-Ahli SFC', 'Al-Ahli SC'),
#  ('AOK Kerkyra', 'AO Kerkyra'),
#  ('Dinamo SPb', 'Dinamo'),
#  ('SK Beveren', 'KSK Beveren'),
#  ('SC Cambuur-Leeuwarden', 'Cambuur'),
#  ('Portimonense 23', 'Portimonense'),
#  ('Krasnodar', 'Kolos Krasnodar'),
#  ('Guadalajara', 'CD Guadalajara'),
#  ('Barletta CS', 'Barletta'),
#  ('Logroñés', 'CD Logroñés'),
#  ('Barnsley FC', 'Barnsley'),
#  ('PSV Eindhoven', 'PSV'),
#  ('Maastricht', 'MVV Maastricht'),
#  ('CD Fátima SAD', 'CD Fátima'),
#  ('Ternana U.', 'Ternana'),
#  ('Nacional', 'Atl. Nacional')]

# %%
# Applying these new mappings to end the fixing process for club namings
transfer_df["source_club"] = transfer_df["source_club"].replace(csv_mapping)
transfer_df["target_club"] = transfer_df["target_club"].replace(csv_mapping)

# %%
# Checking if new self-loops are then generated, because of different namings of the same club for source and target club
self_loops_df = transfer_df[
    transfer_df["source_club"] == transfer_df["target_club"]
].copy()

print("Self-loop transfers after mapping:", len(self_loops_df))

self_loops_df[
    ["player_name", "source_club", "target_club", "season"]
].head(20)
# Out:
# Self-loop transfers after mapping: 4930
#          player_name     source_club     target_club     season
# 14      Darren Eadie         Norwich         Norwich  1992/1993
# 15      Andy Johnson         Norwich         Norwich  1992/1993
# 63    Steve Williams        Coventry        Coventry  1992/1993
# 64     Tony Sheridan        Coventry        Coventry  1992/1993
# 84    Niall Thompson  Crystal Palace  Crystal Palace  1992/1993
# 85       George Ndah  Crystal Palace  Crystal Palace  1992/1993
# 97   Craig Armstrong      Nottingham      Nottingham  1992/1993
# 98      Steve Guinan      Nottingham      Nottingham  1992/1993
# 108      Lee Durrant         Ipswich         Ipswich  1992/1993
# 109      Adam Tanner         Ipswich         Ipswich  1992/1993
# 162     Mark Tinkler           Leeds           Leeds  1992/1993
# 163   Paul Pettinger           Leeds           Leeds  1992/1993
# 268   David Unsworth         Everton         Everton  1992/1993
# 269     Chris Priest         Everton         Everton  1992/1993
# 356   Andrew Couzens           Leeds           Leeds  1992/1993
# 420     Ade Akinbiyi         Norwich         Norwich  1993/1994
# 421    Andy Marshall         Norwich         Norwich  1993/1994
# 422      Deryn Brace         Norwich         Norwich  1993/1994
# 478    Willie Boland        Coventry        Coventry  1993/1994
# 562        Mark Ford           Leeds           Leeds  1993/1994

# %%
# Eliminating those self-loops
transfer_df = transfer_df[
    transfer_df["source_club"] != transfer_df["target_club"]
].copy()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
# Adding another field to be able to assign a league to each of the clubs present in the data

# If we have a club name that does not belong to any of the 9 leagues we have, we will asign a label as "Other" external league


# Creating the mapping dictionary of clubes and their leagues. Mapping from known clubs to their league
club_to_league = (
    transfer_df
    .dropna(subset=["target_club", "source_league"])
    .drop_duplicates(subset=["target_club"])
    .set_index("target_club")["source_league"]
    .to_dict()
)



# Using this dictionary to add a label feature in the dataframe, where we assign the league group at each source and target club of a transfer register

# Creating the label for the source group
transfer_df["source_league_group"] = (
    transfer_df["source_club"]
    .map(club_to_league)
    .fillna("Other")
)

# Creating the label for the target club
transfer_df["target_league_group"] = (
    transfer_df["target_club"]
    .map(club_to_league)
    .fillna("Other")
)

# %%
club_to_league
# Out:
# {'Middlesbrough': 'english_premier_league',
#  'Norwich': 'english_premier_league',
#  'Athletic': 'english_premier_league',
#  'Queens Park Rangers': 'english_premier_league',
#  'Sheffield Wednesday': 'english_premier_league',
#  'AFC Wimbledon': 'english_premier_league',
#  'Coventry': 'english_premier_league',
#  'Manchester United': 'english_premier_league',
#  'Crystal Palace': 'english_premier_league',
#  'Nottingham': 'english_premier_league',
#  'Ipswich': 'english_premier_league',
#  'Arsenal FC': 'english_premier_league',
#  'Chelsea FC': 'english_premier_league',
#  'Aston Villa': 'english_premier_league',
#  'Leeds': 'english_premier_league',
#  'Sheffield United': 'english_premier_league',
#  'Manchester City': 'english_premier_league',
#  'Southampton FC': 'english_premier_league',
#  'Blackburn': 'english_premier_league',
#  'Tottenham': 'english_premier_league',
#  'Liverpool FC': 'english_premier_league',
#  'Everton': 'english_premier_league',
#  'Newcastle': 'english_premier_league',
#  'West Ham': 'english_premier_league',
#  'Swindon': 'english_premier_league',
#  'Leicester City': 'english_premier_league',
#  'Bolton': 'english_premier_league',
#  'Sunderland': 'english_premier_league',
#  'Derby': 'english_premier_league',
#  'Barnsley': 'english_premier_league',
#  'Charlton': 'english_premier_league',
#  'Bradford': 'english_premier_league',
#  'Waterford FC': 'english_premier_league',
#  'Fulham': 'english_premier_league',
#  'West Brom': 'english_premier_league',
#  'Birmingham': 'english_premier_league',
#  'Portsmouth': 'english_premier_league',
#  'Wanderers': 'english_premier_league',
#  'Reading': 'english_premier_league',
#  'Stoke': 'english_premier_league',
#  'Hull': 'english_premier_league',
#  'Burnley FC': 'english_premier_league',
#  'Blackpool': 'english_premier_league',
#  'Swansea': 'english_premier_league',
#  'Cardiff': 'english_premier_league',
#  'AFC Bournemouth': 'english_premier_league',
#  'Brighton': 'english_premier_league',
#  'Huddersfield': 'english_premier_league',
#  'Brentford': 'english_premier_league',
#  'Millwall': 'english_championship',
#  'Preston': 'english_championship',
#  'Rotherham': 'english_championship',
#  'Crewe': 'english_championship',
#  'Gillingham': 'english_championship',
#  'Plymouth': 'english_championship',
#  'Luton': 'english_championship',
#  'Southend': 'english_championship',
#  'Colchester': 'english_championship',
#  'Scunthorpe': 'english_championship',
#  'Bristol': 'english_championship',
#  'Doncaster': 'english_championship',
#  'Peterborough': 'english_championship',
#  'Yeovil': 'english_championship',
#  'Milton Keynes Dons': 'english_championship',
#  'Burton': 'english_championship',
#  'AC Le Havre': 'french_ligue1',
#  'Union Sportive Valenciennes-Anzin Arrondissement': 'french_ligue1',
#  'Caen': 'french_ligue1',
#  'Nîmes': 'french_ligue1',
#  'LOSC Lille': 'french_ligue1',
#  'Olympique Lyon': 'french_ligue1',
#  'FC Nantes': 'french_ligue1',
#  'Montpellier': 'french_ligue1',
#  'Lens': 'french_ligue1',
#  'FC Sochaux': 'french_ligue1',
#  'Bordeaux': 'french_ligue1',
#  'RC Strasbourg Alsace': 'french_ligue1',
#  'AS Saint-Étienne': 'french_ligue1',
#  'Paris Saint-Germain': 'french_ligue1',
#  'Sporting': 'french_ligue1',
#  'FC Toulouse': 'french_ligue1',
#  'FC Metz': 'french_ligue1',
#  'AJ Auxerre': 'french_ligue1',
#  'Marseille': 'french_ligue1',
#  'AS Monaco': 'french_ligue1',
#  'Angers SCO': 'french_ligue1',
#  'FC Martigues': 'french_ligue1',
#  'AS Cannes': 'french_ligue1',
#  'SC Bastia': 'french_ligue1',
#  'OGC Nice': 'french_ligue1',
#  'Stade Rennais': 'french_ligue1',
#  'FC Gueugnon': 'french_ligue1',
#  'EA Guingamp': 'french_ligue1',
#  'AS Nancy': 'french_ligue1',
#  'Châteauroux': 'french_ligue1',
#  'FC Lorient': 'french_ligue1',
#  'Association Troyes Aube Champagne': 'french_ligue1',
#  'CS Sedan': 'french_ligue1',
#  'ESTAC Troyes': 'french_ligue1',
#  'AC Ajaccio': 'french_ligue1',
#  'Le Mans Union Club 72': 'french_ligue1',
#  'FC Istres': 'french_ligue1',
#  'Valenciennes': 'french_ligue1',
#  'Grenoble': 'french_ligue1',
#  'Boulogne': 'french_ligue1',
#  'Athlétic Club Arlésien': 'french_ligue1',
#  'Brest': 'french_ligue1',
#  'FC Évian Thonon Gaillard': 'french_ligue1',
#  'Dijon': 'french_ligue1',
#  'Stade Reims': 'french_ligue1',
#  'GFC Ajaccio': 'french_ligue1',
#  'Amiens SC': 'french_ligue1',
#  'Clermont': 'french_ligue1',
#  '1.FC Saarbrücken': 'german_bundesliga',
#  'SG Wattenscheid 09': 'german_bundesliga',
#  'Bayer 05 Uerdingen': 'german_bundesliga',
#  'SV Werder Bremen': 'german_bundesliga',
#  'VfL Bochum': 'german_bundesliga',
#  'Stuttgart': 'german_bundesliga',
#  'Karlsruher SC': 'german_bundesliga',
#  'Hamburg': 'german_bundesliga',
#  'FC Schalke 04': 'german_bundesliga',
#  'Bayern Munich': 'german_bundesliga',
#  'Eintracht Frankfurt': 'german_bundesliga',
#  'Borussia Mönchengladbach': 'german_bundesliga',
#  'Borussia Dortmund': 'german_bundesliga',
#  'Bayer 04 Leverkusen': 'german_bundesliga',
#  '1.FC Nuremberg': 'german_bundesliga',
#  '1. FC Köln': 'german_bundesliga',
#  '1.FC Kaiserslautern': 'german_bundesliga',
#  'Dynamo Dresden': 'german_bundesliga',
#  'VfB Leipzig': 'german_bundesliga',
#  'SC Freiburg': 'german_bundesliga',
#  'Duisburg': 'german_bundesliga',
#  'TSV 1860': 'german_bundesliga',
#  'FC St. Pauli': 'german_bundesliga',
#  'KFC Uerdingen': 'german_bundesliga',
#  'FC Hansa Rostock': 'german_bundesliga',
#  'Fortuna': 'german_bundesliga',
#  'Arminia Bielefeld': 'german_bundesliga',
#  'VfL Wolfsburg': 'german_bundesliga',
#  'Hertha BSC': 'german_bundesliga',
#  'SpVgg Unterhaching': 'german_bundesliga',
#  'SSV Ulm 1846': 'german_bundesliga',
#  'Energie Cottbus': 'german_bundesliga',
#  'Hannover 96': 'german_bundesliga',
#  '1.FSV Mainz 05': 'german_bundesliga',
#  'Aachen': 'german_bundesliga',
#  'Hoffenheim': 'german_bundesliga',
#  'FC Augsburg': 'german_bundesliga',
#  'Greuther Fürth': 'german_bundesliga',
#  'Bra': 'german_bundesliga',
#  'Paderborn': 'german_bundesliga',
#  'FC Ingolstadt': 'german_bundesliga',
#  'Darmstadt': 'german_bundesliga',
#  'RB Leipzig': 'german_bundesliga',
#  '1.FC Union Berlin': 'german_bundesliga',
#  'AC Fiorentina': 'italian_serieA',
#  'Napoli': 'italian_serieA',
#  'Delfino Pescara 1936': 'italian_serieA',
#  'Cagliari': 'italian_serieA',
#  'Ancona': 'italian_serieA',
#  'Sampdoria': 'italian_serieA',
#  'Atalanta': 'italian_serieA',
#  'Foggia': 'italian_serieA',
#  'GE Juventus-SC': 'italian_serieA',
#  'AC Milan': 'italian_serieA',
#  'Torino': 'italian_serieA',
#  'Udinese': 'italian_serieA',
#  'Lazio': 'italian_serieA',
#  'Genoa': 'italian_serieA',
#  'AC Parma': 'italian_serieA',
#  'FC Internazionale': 'italian_serieA',
#  'Brescia': 'italian_serieA',
#  'AS Roma': 'italian_serieA',
#  'AC Reggiana': 'italian_serieA',
#  'Cremonese': 'italian_serieA',
#  'Piacenza': 'italian_serieA',
#  'Lecce': 'italian_serieA',
#  'Calcio Padova': 'italian_serieA',
#  'AS Bari': 'italian_serieA',
#  'Vicenza': 'italian_serieA',
#  'Bologna': 'italian_serieA',
#  'AC Perugia': 'italian_serieA',
#  'Hellas Verona': 'italian_serieA',
#  'Empoli': 'italian_serieA',
#  'AC Venezia 1907': 'italian_serieA',
#  'Salernitana': 'italian_serieA',
#  'Reggina': 'italian_serieA',
#  'Chievo': 'italian_serieA',
#  'Como': 'italian_serieA',
#  'Modena': 'italian_serieA',
#  'AC Siena': 'italian_serieA',
#  'Parma': 'italian_serieA',
#  'Palermo': 'italian_serieA',
#  'FC Messina': 'italian_serieA',
#  'AS Livorno': 'italian_serieA',
#  'Treviso': 'italian_serieA',
#  'Ascoli': 'italian_serieA',
#  'Catania': 'italian_serieA',
#  'AC Cesena': 'italian_serieA',
#  'Novara': 'italian_serieA',
#  'Sassuolo': 'italian_serieA',
#  'Carpi': 'italian_serieA',
#  'Frosinone': 'italian_serieA',
#  'Crotone': 'italian_serieA',
#  'Benevento': 'italian_serieA',
#  'SPAL': 'italian_serieA',
#  'Spezia': 'italian_serieA',
#  'Venezia': 'italian_serieA',
#  'AC Monza': 'italian_serieA',
#  'Real Sociedad': 'spanish_laliga',
#  'Cádiz': 'spanish_laliga',
#  'Oviedo': 'spanish_laliga',
#  'Albacete': 'spanish_laliga',
#  'Valencia CF': 'spanish_laliga',
#  'Celta': 'spanish_laliga',
#  'Deportivo': 'spanish_laliga',
#  'RCD Espanyol': 'spanish_laliga',
#  'Atletico de Madrid': 'spanish_laliga',
#  'CD Tenerife': 'spanish_laliga',
#  'Real Madrid': 'spanish_laliga',
#  'Sevilla': 'spanish_laliga',
#  'Rayo': 'spanish_laliga',
#  'CA Osasuna': 'spanish_laliga',
#  'CD Logroñés': 'spanish_laliga',
#  'Real Zaragoza': 'spanish_laliga',
#  'FC Barcelona': 'spanish_laliga',
#  'Racing Santander': 'spanish_laliga',
#  'UE Lleida': 'spanish_laliga',
#  'Real Valladolid CF': 'spanish_laliga',
#  'Compostela': 'spanish_laliga',
#  'Real Betis': 'spanish_laliga',
#  'CP Mérida': 'spanish_laliga',
#  'Salamanca': 'spanish_laliga',
#  'Hércules CF': 'spanish_laliga',
#  'CF Extremadura': 'spanish_laliga',
#  'Mallorca': 'spanish_laliga',
#  'Villarreal FC': 'spanish_laliga',
#  'Málaga': 'spanish_laliga',
#  'CD Numancia': 'spanish_laliga',
#  'Las Palmas': 'spanish_laliga',
#  'Recreativo Huelva': 'spanish_laliga',
#  'Real Murcia': 'spanish_laliga',
#  'Getafe': 'spanish_laliga',
#  'Levante UD': 'spanish_laliga',
#  'Gimnàstic': 'spanish_laliga',
#  'UD Almería': 'spanish_laliga',
#  'Xerez CD': 'spanish_laliga',
#  'Granada 74 CF': 'spanish_laliga',
#  'Elche CF': 'spanish_laliga',
#  'SD Eibar': 'spanish_laliga',
#  'Córdoba CF': 'spanish_laliga',
#  'CD Leganés': 'spanish_laliga',
#  'Girona FC': 'spanish_laliga',
#  'SD Huesca': 'spanish_laliga',
#  'FC Porto': 'portugese_ligaNOS',
#  'Benfica': 'portugese_ligaNOS',
#  'Boavista': 'portugese_ligaNOS',
#  'CS Marítimo': 'portugese_ligaNOS',
#  'Farense': 'portugese_ligaNOS',
#  'Belenenses': 'portugese_ligaNOS',
#  'Beira-Mar': 'portugese_ligaNOS',
#  'Gil Vicente': 'portugese_ligaNOS',
#  'FC Paços de Ferreira': 'portugese_ligaNOS',
#  'Guimarães': 'portugese_ligaNOS',
#  'Braga': 'portugese_ligaNOS',
#  'Estoril': 'portugese_ligaNOS',
#  'FC Famalicão': 'portugese_ligaNOS',
#  'SC Salgueiros': 'portugese_ligaNOS',
#  'FC Tirsense': 'portugese_ligaNOS',
#  'Espinho': 'portugese_ligaNOS',
#  'Chaves': 'portugese_ligaNOS',
#  'Setúbal': 'portugese_ligaNOS',
#  'Clube Futebol Estrela da Amadora': 'portugese_ligaNOS',
#  'CF União Madeira': 'portugese_ligaNOS',
#  'Leiria': 'portugese_ligaNOS',
#  'Leça': 'portugese_ligaNOS',
#  'CA Felgueiras': 'portugese_ligaNOS',
#  'Campomaiorense': 'portugese_ligaNOS',
#  'Rio Ave': 'portugese_ligaNOS',
#  'Académica': 'portugese_ligaNOS',
#  'Varzim': 'portugese_ligaNOS',
#  'Alverca': 'portugese_ligaNOS',
#  'CD Santa Clara': 'portugese_ligaNOS',
#  'Desportivo Aves': 'portugese_ligaNOS',
#  'CD El Nacional': 'portugese_ligaNOS',
#  'Moreirense': 'portugese_ligaNOS',
#  'FC Penafiel': 'portugese_ligaNOS',
#  'Naval': 'portugese_ligaNOS',
#  'Leixões': 'portugese_ligaNOS',
#  'CD Trofense': 'portugese_ligaNOS',
#  'Olhanense': 'portugese_ligaNOS',
#  'Portimonense': 'portugese_ligaNOS',
#  'CD Feirense': 'portugese_ligaNOS',
#  'Arouca': 'portugese_ligaNOS',
#  'CD Tondela': 'portugese_ligaNOS',
#  'FC Vizela': 'portugese_ligaNOS',
#  'Casa Pia': 'portugese_ligaNOS',
#  "Dordrecht'90": 'dutch_eredivisie',
#  'Go Ahead': 'dutch_eredivisie',
#  'FC Volendam': 'dutch_eredivisie',
#  'Ajax Amsterdam': 'dutch_eredivisie',
#  'Vitesse': 'dutch_eredivisie',
#  'Sparta': 'dutch_eredivisie',
#  'Den Bosch': 'dutch_eredivisie',
#  'Willem': 'dutch_eredivisie',
#  'Cambuur': 'dutch_eredivisie',
#  'MVV': 'dutch_eredivisie',
#  'PSV': 'dutch_eredivisie',
#  'Twente Enschede FC': 'dutch_eredivisie',
#  'RKC': 'dutch_eredivisie',
#  'Feyenoord': 'dutch_eredivisie',
#  'FC Groningen': 'dutch_eredivisie',
#  'FC Utrecht': 'dutch_eredivisie',
#  'Roda JC': 'dutch_eredivisie',
#  'NAC Breda': 'dutch_eredivisie',
#  'VVV': 'dutch_eredivisie',
#  'Heerenveen': 'dutch_eredivisie',
#  'NEC': 'dutch_eredivisie',
#  'De Graafschap': 'dutch_eredivisie',
#  'AZ': 'dutch_eredivisie',
#  'RBC': 'dutch_eredivisie',
#  'FC Zwolle': 'dutch_eredivisie',
#  'Excelsior': 'dutch_eredivisie',
#  'ADO': 'dutch_eredivisie',
#  'Heracles': 'dutch_eredivisie',
#  'PEC Zwolle': 'dutch_eredivisie',
#  'Dordrecht': 'dutch_eredivisie',
#  'Emmen': 'dutch_eredivisie',
#  'Rotor Volgograd': 'russian_premier_liga',
#  'Dinamo': 'russian_premier_liga',
#  'Энергия-Текстиль': 'russian_premier_liga',
#  'Lokomotiv Moscow': 'russian_premier_liga',
#  'Торпедо-Лужники': 'russian_premier_liga',
#  'Uralmash': 'russian_premier_liga',
#  'CSKA Moscow': 'russian_premier_liga',
#  'КАМАЗ-Чаллы': 'russian_premier_liga',
#  'Sochi': 'russian_premier_liga',
#  'Krylya Sovetov Samara': 'russian_premier_liga',
#  'Ocean Nakhodka': 'russian_premier_liga',
#  'Rostselmash': 'russian_premier_liga',
#  'Пресня': 'russian_premier_liga',
#  'Lokomotiv Nizhniy Novgorod': 'russian_premier_liga',
#  'Luch': 'russian_premier_liga',
#  'Lada-Togliatti-VAZ Togliatti': 'russian_premier_liga',
#  'Chernomorets Novorossijsk': 'russian_premier_liga',
#  'Baltika': 'russian_premier_liga',
#  'Zenit': 'russian_premier_liga',
#  'Shinnik': 'russian_premier_liga',
#  'FK Tyumen': 'russian_premier_liga',
#  'Факел-Воронеж': 'russian_premier_liga',
#  'ФК Элиста': 'russian_premier_liga',
#  'Torpedo': 'russian_premier_liga',
#  'Saturn REN-TV': 'russian_premier_liga',
#  'Anzhi': 'russian_premier_liga',
#  'Sokol Saratov': 'russian_premier_liga',
#  'Torpedo-ZiL': 'russian_premier_liga',
#  'Rubin Kazan': 'russian_premier_liga',
#  'Saturn': 'russian_premier_liga',
#  'FK Rostov': 'russian_premier_liga',
#  'Amkar': 'russian_premier_liga',
#  'Alania': 'russian_premier_liga',
#  'Kuban Krasnodar': 'russian_premier_liga',
#  'FC Moscow': 'russian_premier_liga',
#  'Tom Tomsk': 'russian_premier_liga',
#  'Terek': 'russian_premier_liga',
#  'FK Khimki': 'russian_premier_liga',
#  'Sibir': 'russian_premier_liga',
#  'Volga Nizhniy Novgorod (- 2016)': 'russian_premier_liga',
#  'FK Krasnodar': 'russian_premier_liga',
#  'Mordovia': 'russian_premier_liga',
#  'Ural': 'russian_premier_liga',
#  'Arsenal Tula': 'russian_premier_liga',
#  'FK Ufa': 'russian_premier_liga',
#  'FK Orenburg': 'russian_premier_liga',
#  'Akhmat': 'russian_premier_liga',
#  'SKA Khabarovsk': 'russian_premier_liga',
#  'FC Tosno (-2018)': 'russian_premier_liga',
#  'Enisey': 'russian_premier_liga',
#  'FK Tambov': 'russian_premier_liga',
#  'FC Sochi': 'russian_premier_liga',
#  'Dynamo M': 'russian_premier_liga',
#  'FC Nizhniy Novgorod': 'russian_premier_liga',
#  'Fakel': 'russian_premier_liga'}

# %%
transfer_df.head()
# Out:
#           club_name       player_name   age     position club_involved_name  \
# 0  Middlesbrough FC      Tommy Wright  26.0  Left Winger          Leicester
# 1  Middlesbrough FC  Jonathan Gittens  28.0      defence        Southampton
# 2  Middlesbrough FC      Chris Morris  28.0   Right-Back             Celtic
# 3  Middlesbrough FC       Ben Roberts  17.0   Goalkeeper           Boro U18
# 4  Middlesbrough FC         Andy Todd  17.0  Centre-Back           Boro U18
#
#        fee transfer_movement transfer_period  fee_cleaned     league_name  \
# 0  €910Th.                in          Summer         0.91  Premier League
# 1  €250Th.                in          Summer         0.25  Premier League
# 2        ?                in          Summer          NaN  Premier League
# 3        -                in          Summer          NaN  Premier League
# 4        -                in          Summer          NaN  Premier League
#
#    year     season  country           source_league    target_club  \
# 0  1992  1992/1993  England  english_premier_league  Middlesbrough
# 1  1992  1992/1993  England  english_premier_league  Middlesbrough
# 2  1992  1992/1993  England  english_premier_league  Middlesbrough
# 3  1992  1992/1993  England  english_premier_league  Middlesbrough
# 4  1992  1992/1993  England  english_premier_league  Middlesbrough
#
#       source_club     source_league_group     target_league_group
# 0  Leicester City  english_premier_league  english_premier_league
# 1  Southampton FC  english_premier_league  english_premier_league
# 2          Celtic                   Other  english_premier_league
# 3            Boro                   Other  english_premier_league
# 4            Boro                   Other  english_premier_league

# %%
# Quick check to see if there still remail academy clubs in our data
import re
import pandas as pd

# Regex pattern to detect U16-U21 variants
u_pattern = r"U\s*-?\s*(16|17|18|19|20|21|23)"

# Checking source_club
source_u_clubs = sorted(
    transfer_df.loc[
        transfer_df["source_club"].astype(str).str.contains(
            u_pattern,
            case=False,
            regex=True,
            na=False
        ),
        "source_club"
    ].unique()
)

# Checking target_club
target_u_clubs = sorted(
    transfer_df.loc[
        transfer_df["target_club"].astype(str).str.contains(
            u_pattern,
            case=False,
            regex=True,
            na=False
        ),
        "target_club"
    ].unique()
)

print("U-teams found in source_club:", len(source_u_clubs))
print(source_u_clubs[:100])

print("\nU-teams found in target_club:", len(target_u_clubs))
print(target_u_clubs[:100])
# Out:
# U-teams found in source_club: 0
# []
#
# U-teams found in target_club: 0
# []
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_25024\1258786109.py:11: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   transfer_df["source_club"].astype(str).str.contains(
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_25024\1258786109.py:24: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   transfer_df["target_club"].astype(str).str.contains(

# %% [markdown]
# ### 3. Constructing the Network Dataset

# %%
# Choosing from all the seasons, the ones we desire to plot
seasons_to_plot = ['2022/2023']

# seasons_to_plot = ['1992/1993', '1993/1994', '1994/1995', '1995/1996', '1996/1997',
#                    '1997/1998', '1998/1999', '1999/2000', '2000/2001', '2001/2002',
#                    '2002/2003', '2003/2004', '2004/2005', '2005/2006', '2006/2007',
#                    '2007/2008', '2008/2009', '2009/2010', '2010/2011', '2011/2012',
#                    '2012/2013', '2013/2014', '2014/2015', '2015/2016', '2016/2017',
#                    '2017/2018', '2018/2019', '2019/2020', '2020/2021', '2021/2022',
#                    '2022/2023']

# %%
# Choosing one season to plot
season_df = transfer_df[transfer_df["season"].isin(seasons_to_plot)].copy()

# %%
season_df.head()
# Out:
#         club_name          player_name   age            position  \
# 22975  Arsenal FC        Gabriel Jesus  25.0      Centre-Forward
# 22976  Arsenal FC  Oleksandr Zinchenko  25.0           Left-Back
# 22977  Arsenal FC         Fábio Vieira  22.0  Attacking Midfield
# 22978  Arsenal FC          Matt Turner  28.0          Goalkeeper
# 22979  Arsenal FC           Marquinhos  19.0        Right Winger
#
#       club_involved_name      fee transfer_movement transfer_period  \
# 22975           Man City  €52.20m                in          Summer
# 22976           Man City  €35.00m                in          Summer
# 22977           FC Porto  €35.00m                in          Summer
# 22978        New England   €6.36m                in          Summer
# 22979          São Paulo   €3.50m                in          Summer
#
#        fee_cleaned     league_name  year     season  country  \
# 22975        52.20  Premier League  2022  2022/2023  England
# 22976        35.00  Premier League  2022  2022/2023  England
# 22977        35.00  Premier League  2022  2022/2023  England
# 22978         6.36  Premier League  2022  2022/2023  England
# 22979         3.50  Premier League  2022  2022/2023  England
#
#                 source_league target_club      source_club  \
# 22975  english_premier_league  Arsenal FC  Manchester City
# 22976  english_premier_league  Arsenal FC  Manchester City
# 22977  english_premier_league  Arsenal FC         FC Porto
# 22978  english_premier_league  Arsenal FC      New England
# 22979  english_premier_league  Arsenal FC     FC São Paulo
#
#           source_league_group     target_league_group
# 22975  english_premier_league  english_premier_league
# 22976  english_premier_league  english_premier_league
# 22977       portugese_ligaNOS  english_premier_league
# 22978                   Other  english_premier_league
# 22979                   Other  english_premier_league

# %%
season_df[season_df['source_club'] == "Girona FC"]
# Out:
#                      club_name    player_name   age            position  \
# 23274          Manchester City  Nahuel Bustos  23.0      Centre-Forward
# 124736             Real Madrid        Reinier  21.0  Attacking Midfield
# 124906           Villarreal CF     Álex Baena  20.0         Left Winger
# 125068  RCD Espanyol Barcelona     Pol Lozano  22.0    Central Midfield
#
#        club_involved_name                      fee transfer_movement  \
# 23274              Girona  End of loanJun 30, 2022                in
# 124736             Girona  End of loanJun 30, 2023                in
# 124906             Girona  End of loanJun 30, 2022                in
# 125068             Girona  End of loanJun 30, 2022                in
#
#        transfer_period  fee_cleaned       league_name  year     season  \
# 23274           Summer          NaN    Premier League  2022  2022/2023
# 124736          Summer          NaN  Primera Division  2022  2022/2023
# 124906          Summer          NaN  Primera Division  2022  2022/2023
# 125068          Summer          NaN  Primera Division  2022  2022/2023
#
#         country           source_league      target_club source_club  \
# 23274   England  english_premier_league  Manchester City   Girona FC
# 124736    Spain          spanish_laliga      Real Madrid   Girona FC
# 124906    Spain          spanish_laliga    Villarreal FC   Girona FC
# 125068    Spain          spanish_laliga     RCD Espanyol   Girona FC
#
#        source_league_group     target_league_group     club_a           club_b
# 23274       spanish_laliga  english_premier_league  Girona FC  Manchester City
# 124736      spanish_laliga          spanish_laliga  Girona FC      Real Madrid
# 124906      spanish_laliga          spanish_laliga  Girona FC    Villarreal FC
# 125068      spanish_laliga          spanish_laliga  Girona FC     RCD Espanyol

# %%
# Building the weighted edge list
# Since for community detection you want an undirected network,
# we sort source/target so A-B and B-A count as the same edge.

season_df["club_a"] = season_df[["source_club", "target_club"]].min(axis=1)
season_df["club_b"] = season_df[["source_club", "target_club"]].max(axis=1)

edge_list = (
    season_df
    .groupby(["club_a", "club_b"])
    .size()
    .reset_index(name="weight")
    .sort_values("weight", ascending=False)
)

edge_list.head(20)
# Out:
#                      club_a              club_b  weight
# 1298                  Cádiz  Real Valladolid CF       5
# 2055  Krylya Sovetov Samara              Sparta       5
# 1296                  Cádiz         Real Madrid       4
# 1823                Fortuna                 MVV       4
# 140                AC Monza   FC Internazionale       4
# 1966          Hellas Verona           Sampdoria       4
# 1934              Guimarães             Rio Ave       4
# 906                Brighton              Fulham       4
# 2091                  Leeds            Millwall       4
# 1925                Grimsby               Luton       4
# 188         AFC Bournemouth               Stoke       4
# 1248            Corinthians               Zenit       4
# 1105                Cardiff           West Brom       4
# 474              Arsenal FC           Marseille       4
# 739              Birmingham             Norwich       4
# 2185        Manchester City      Southampton FC       4
# 2218          Middlesbrough           Rotherham       4
# 1661               FC Sochi             FC Tver       4
# 2479                 Sparta                Ural       4
# 1901              Girona FC         Real Madrid       4

# %%
# Removing self-loops, if any

edge_list = edge_list[edge_list["club_a"] != edge_list["club_b"]].copy()

print("Number of edges:", len(edge_list))
print("Number of clubs:", len(set(edge_list["club_a"]).union(set(edge_list["club_b"]))))
# Out:
# Number of edges: 2543
# Number of clubs: 774

# %%
edge_list.head(30)
# Out:
#                      club_a              club_b  weight
# 1298                  Cádiz  Real Valladolid CF       5
# 2055  Krylya Sovetov Samara              Sparta       5
# 1296                  Cádiz         Real Madrid       4
# 1823                Fortuna                 MVV       4
# 140                AC Monza   FC Internazionale       4
# 1966          Hellas Verona           Sampdoria       4
# 1934              Guimarães             Rio Ave       4
# 906                Brighton              Fulham       4
# 2091                  Leeds            Millwall       4
# 1925                Grimsby               Luton       4
# 188         AFC Bournemouth               Stoke       4
# 1248            Corinthians               Zenit       4
# 1105                Cardiff           West Brom       4
# 474              Arsenal FC           Marseille       4
# 739              Birmingham             Norwich       4
# 2185        Manchester City      Southampton FC       4
# 2218          Middlesbrough           Rotherham       4
# 1661               FC Sochi             FC Tver       4
# 2479                 Sparta                Ural       4
# 1901              Girona FC         Real Madrid       4
# 2030              KS Samara              Sparta       4
# 843           Botev Plovdiv        FK Krasnodar       3
# 1798              Feyenoord          Hertha BSC       3
# 1854         GE Juventus-SC       Juve Next Gen       3
# 1882                 Getafe           SD Huesca       3
# 1812              Fleetwood               Luton       3
# 1807              Feyenoord              Sparta       3
# 871               Brentford          Burnley FC       3
# 1960          Hellas Verona               Lazio       3
# 880               Brentford            OGC Nice       3

# %%
# Building a  NetworkX graph

import networkx as nx

G = nx.from_pandas_edgelist(
    edge_list,
    source="club_a",
    target="club_b",
    edge_attr="weight",
    create_using=nx.Graph()
)

print(G)
# Out:
# Graph with 774 nodes and 2543 edges

# %%
# Plotting the Network
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 10))

pos = nx.spring_layout(
    G,
    k=0.25,
    iterations=50,
    seed=42,
    weight="weight"
)

node_sizes = [50 + 20 * G.degree(node) for node in G.nodes()]
edge_widths = [0.3 + 0.4 * G[u][v]["weight"] for u, v in G.edges()]

nx.draw_networkx_nodes(
    G,
    pos,
    node_size=node_sizes,
    alpha=0.75
)

nx.draw_networkx_edges(
    G,
    pos,
    width=edge_widths,
    alpha=0.25
)

# Label only the most connected clubs
top_nodes = sorted(G.degree, key=lambda x: x[1], reverse=True)[:25]
labels = {node: node for node, degree in top_nodes}

nx.draw_networkx_labels(
    G,
    pos,
    labels=labels,
    font_size=8
)

plt.title(f"European Football Transfer Network - {seasons_to_plot[0]} to {seasons_to_plot[-1]}")
plt.axis("off")
plt.show()

# %% [markdown]
# ### 4. Basic Network Characterization
#
# Here we study basic metrics to obtain useful information that allows us to have an idea of what the network looks like, and describe its basic structure.

# %%
print("Number of nodes: ", G.number_of_nodes())
print("Number of edges: ", G.number_of_edges())
print("Density: ", nx.density(G))
print("Average clustering: ", nx.average_clustering(G))
print("Number of connected components: ", nx.number_connected_components(G))
# Out:
# Number of nodes:  774
# Number of edges:  2543
# Density:  0.008500723714779492
# Average clustering:  0.09050222848535622
# Number of connected components:  1

# %%
# Plotting the degree distribution of our Network

degrees = [d for n, d in G.degree()]

import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.hist(
    degrees,
    bins=30
)

plt.xlabel("Degree")
plt.ylabel("Frequency")
plt.title("Degree Distribution")

plt.show()

# %%
# Checking which clubs are hubs of our network (clubs that have the most amount of transfers during that season)
top_degree_nodes = sorted(
    G.degree, # this functionality returns pairs (node, degree)
    key=lambda x: x[1], # we order the list of pairs by the second value of the pair (the degree)
    reverse=True # we order from high to low
)[:20] # we take the top 20 teams

top_degree_nodes
# Out:
# [('Benfica', 50),
#  ('Sparta', 49),
#  ('Sporting', 44),
#  ('FC Schalke 04', 37),
#  ('Arsenal FC', 36),
#  ('Manchester City', 36),
#  ('Chelsea FC', 34),
#  ('FK Khimki', 34),
#  ('Marseille', 33),
#  ('Without Club', 33),
#  ('Hellas Verona', 31),
#  ('OGC Nice', 31),
#  ('Burnley FC', 30),
#  ('FC Paços de Ferreira', 30),
#  ('Wanderers', 30),
#  ('Huddersfield', 30),
#  ('Estoril', 30),
#  ('Nottingham', 30),
#  ('Brighton', 29),
#  ('Feyenoord', 29)]

# %% [markdown]
# ### 5. Community Detection

# %%
pip install python-louvain
# Out:
# Collecting python-louvain
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: networkx in c:\users\lenovo\miniconda3\lib\site-packages (from python-louvain) (3.5)
# Requirement already satisfied: numpy in c:\users\lenovo\miniconda3\lib\site-packages (from python-louvain) (2.3.3)
# Building wheels for collected packages: python-louvain
#   Building wheel for python-louvain (setup.py): started
#   Building wheel for python-louvain (setup.py): finished with status 'done'
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9402 sha256=2df1680b2b45c44c3a5f11cfea320e205f6f5b42a859d55128d00bd190e4f5b1
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\ee\52\54\7ecd0f1ebf5f5a8466f70a27ed2b94d20b955376879d6159c5
# Successfully built python-louvain
# Installing collected packages: python-louvain
# Successfully installed python-louvain-0.16
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'python-louvain' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'python-louvain'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
# Applying Louvain Algorithm

import community as community_louvain  # pip install python-louvain

# Louvain partition
partition = community_louvain.best_partition(
    G,
    weight='weight',   # usa los pesos de las aristas
    random_state=42
)

# partition es un diccionario: nodo -> comunidad
list(partition.items())[:20]
# Out:
# [('Cádiz', 0),
#  ('Real Valladolid CF', 0),
#  ('Krylya Sovetov Samara', 1),
#  ('Sparta', 1),
#  ('Real Madrid', 0),
#  ('Fortuna', 2),
#  ('MVV', 2),
#  ('AC Monza', 3),
#  ('FC Internazionale', 3),
#  ('Hellas Verona', 3),
#  ('Sampdoria', 3),
#  ('Guimarães', 4),
#  ('Rio Ave', 4),
#  ('Brighton', 5),
#  ('Fulham', 5),
#  ('Leeds', 5),
#  ('Millwall', 5),
#  ('Grimsby', 5),
#  ('Luton', 5),
#  ('AFC Bournemouth', 5)]

# %%
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import networkx as nx

# Colores
cmap = cm.get_cmap('tab20')

plt.figure(figsize=(14,10))
pos = nx.spring_layout(G, seed=42, weight='weight')

nx.draw_networkx_nodes(
    G, pos,
    node_color=[cmap(partition[n] % 20) for n in G.nodes()],
    node_size=50
)
nx.draw_networkx_edges(G, pos, alpha=0.2)
plt.title("Louvain Communities")
plt.axis("off")
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_25024\3821008453.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20')

# %%
from collections import defaultdict

# Grouping clubs by community
communities = defaultdict(list)

for club, community_id in partition.items():
    communities[community_id].append(club)

# Printing communities
for community_id, clubs in communities.items():
    
    print(f"\nCOMMUNITY {community_id}")
    print(f"Number of clubs: {len(clubs)}")
    print(sorted(clubs))
# Out:
# COMMUNITY 0
# Number of clubs: 83
# ['AS Red Star 93', 'Adana Demirspor', 'Al-Ahli SC', 'Albacete', 'Annan Athletic', 'Arsenal Sarandí', 'Aston Villa', 'Atletico de Madrid', 'Barça', 'Basaksehir', 'Burgos CF', 'CA Osasuna', 'CD Alcoyano', 'CD Leganés', 'CD Logroñés', 'CD Lugo', 'CD Mirandés', 'CD Tenerife', 'CF Fuenlabrada', 'Cartagena FC', 'Celta', 'Central', 'Chelsea FC', 'Chicago', 'CyD Leonesa', 'Cádiz', 'Degerfors', 'Dep. La Coruña', 'Deportivo', 'Dynamo 2 Kyiv', 'Elche CF', 'Elche Ilicitano', 'Envigado', 'FC Barcelona', 'FC Juárez', 'FC Lugano', 'Flamengo', 'Fluminense', 'Galatasaray', 'Getafe', 'Girona FC', 'Granada 74 CF', 'Hammarby', 'Independiente', 'Karagümrük', 'Las Palmas', 'Levante UD', 'Mallorca', 'Molde', 'Monterrey', 'Málaga', 'New York City', 'Oviedo', 'PAS Lamia', 'Peñarol', 'Ponferradina', 'RCD Espanyol', 'Racing Santander', 'Rayo', 'Real Betis', 'Real Cartagena', 'Real Madrid', 'Real Sociedad', 'Real Valladolid CF', 'Real Zaragoza', 'Rushden & Diam.', 'SD Eibar', 'SD Huesca', 'San Lorenzo', 'Santos', 'Sevilla', 'Spurs', 'Tigres', 'Tottenham', 'UD Almería', 'UD Ibiza', 'Udinese', 'Unionistas CF', 'Valencia CF', 'Valladolid Prom', 'Villarreal FC', 'Waterford FC', 'Watford']
#
# COMMUNITY 1
# Number of clubs: 102
# ['AEK Athens', 'Akhmat', 'Alania', 'Arda Kardzhali', 'Argentinos', 'Arsenal Tula', 'Atl. Levante', 'B. Banja Luka', 'BATE Borisov', 'Baltika', 'Bijelo Brdo', 'CRFSO Smolensk', 'Cerro Porteño', 'Chaika Pes.', 'Charlotte', 'Corinthians', 'Cukaricki', 'DFK Dainava', 'DYuSSh Spartak', 'Din-Gaz Tyumen', 'Djurgården', 'Dolgoprudnyi', 'Dynamo 2', 'Dynamo M', 'Eindhoven', 'Enisey', 'FC Astana', 'FC Nizhniy Novgorod', 'FC Olympic', 'FC Saburtalo', 'FC Sheriff', 'FC Sochi', 'FC São Paulo', 'FC Tver', 'FC U Craiova', 'FCV Farul', 'FK Khimki', 'FK Orenburg', 'FK Rostov', 'FK Sochi', 'FK Turan', 'Fakel', 'Forte Taganrog', 'Gastello Ufa', 'Gazovik Orenburg', 'Gornik', 'Guaraní', 'HNK Sibenik', 'Helsingborg', 'Irtysh', 'KS Samara', 'Kolos Krasnodar', 'Konyaspor', 'Krasava', 'Krasnodar', 'Krylya Sovetov Samara', 'Kuban', 'Lanús', 'Leningradets', 'Loko Moscow', 'Loko-Kazanka M.', 'Lokomotiv Moscow', 'M. Lipetsk', 'Maccabi Netanya', 'Michalovce', 'Neftekhimik', 'Norrköping', 'Novosibirsk', 'Odds BK', 'Odense BK', 'Pakhtakor', 'Pari NN', 'Qyzyljar', 'Racing Club', 'Rad', 'Rodina Moscow', 'Rostov', 'Rotor Volgograd', 'Rubin Kazan', 'SKA Khabarovsk', 'Saprissa', 'Shakhter K.', 'Slaven Belupo', 'Soligorsk', 'Sparta', 'Standard', 'Tom Tomsk', 'Torpedo', 'UTA Arad', 'Ulsan Hyundai', 'Ural', 'Vancouver', 'Veles Moscow', 'Vissel Kobe', 'Vojvodina', 'Volgar', 'Vozdovac', 'Warta Poznan', 'Zenit', 'Znamya Truda', 'Zrinjski Mostar', 'Zvezda S-Pb']
#
# COMMUNITY 2
# Number of clubs: 172
# ['1. FC Köln', '1.FC Heidenheim', "1.FC K'lautern", '1.FC Magdeburg', '1.FC Nuremberg', '1.FC Union Berlin', 'A. Bielefeld', 'A. Klagenfurt', 'ADO', 'AZ', 'Aalesund', 'Aarhus GF', 'Aberdeen FC', 'Académico Viseu', 'Ajax Amsterdam', 'Almere City', 'América', 'Anderlecht', 'Ankaragücü', 'Antwerp', 'Atl. Nacional', 'Austria Vienna', 'B. Dortmund', 'BSC Young Boys', 'Bay. Leverkusen', 'Bayer 04 Leverkusen', 'Bayern Munich', 'Beerschot V.A.', 'Besiktas', 'Bogotá FC', 'Bohemians', 'Bologna', "Bor. M'gladbach", 'Borussia Dortmund', 'Borussia Mönchengladbach', 'Boston Utd', 'C. Rizespor', 'CA Atenas', 'CD Cruz Azul', 'Cambuur', 'Cercle Brugge', 'Club NXT', 'Colo Colo', 'Colorado', 'Copenhagen', 'Coritiba FC', 'Dallas', 'Darmstadt', 'De Graafschap', 'Den Bosch', 'Dinamo', 'Dordrecht', 'Dynamo Dresden', 'Eintracht Frankfurt', 'Elfsborg', 'Erzgebirge Aue', 'Estudiantes', 'Ettifaq FC', 'Excelsior', 'FC Augsburg', 'FC Bayern', 'FC Flora', 'FC Groningen', 'FC Midtjylland', 'FC Schalke 04', 'FC St. Pauli', 'FC Toulouse', 'FC Twente', 'FC Utrecht', 'FC Volendam', 'Ferencváros', 'Feyenoord', 'Fortuna', 'Fortuna Sittard', 'Gaziantep FK', 'Giresunspor', 'Go Ahead', 'Godoy Cruz', 'Grasshoppers', 'Greuther Fürth', 'Göztepe', 'HJK Helsinki', 'HNK Gorica', 'HNK Rijeka', 'Hajduk Split', 'Hallescher FC', 'Hamburg', 'Hannover 96', 'Heerenveen', 'Helmond Sport', 'Hertha BSC', 'Hoffenheim', 'Imolese', 'Jahn Regensburg', 'Júbilo Iwata', 'K. Offenbach', 'KAS Eupen', 'KSK Beveren', 'KSK Lierse Kem.', 'KV Mechelen', 'KV Oostende', 'Kairat Almaty', 'Kansas City', 'Karlsruher SC', 'Kasimpasa', 'Kidderminster', 'Koninklijke HFC', 'KuPS', 'Laranja (PR)', 'Lech Poznan', 'Legia Warszawa', 'MVV', 'Malmö', 'Miami', 'Montréal', 'NAC Breda', 'NEC', 'NK Celje', 'NK Lokomotiva', 'NK Osijek', 'Nordsjaelland', 'OFI Crete FC', 'Oberhausen', 'PAOK Salonika', 'PAS Giannina', 'PEC Zwolle', 'PSV', 'Paderborn', 'Panathinaikos', 'Philadelphia', 'Podbeskidzie', 'RB Leipzig', 'RKC', 'Rapid Vienna', 'Riga', 'Roda JC', 'Ross County', 'SC Freiburg', 'SC Verl', 'SCR Altach', 'SKN St. Pölten', 'SV Werder Bremen', 'Salt Lake', 'San Jose', 'Sheff Utd', 'Sheffield United', 'Sint-Truiden', 'Solihull', 'Stabæk Fotball', 'Stal Mielec', 'Stormv. Telstar', 'Strømsgodset', 'Sturm Graz', 'Stuttgart', 'TOP', 'Trabzonspor', 'Tromsø IL', 'Turgutluspor', 'Twente Enschede FC', 'VCU Rams', 'VfL Bochum', 'VfL Wolfsburg', 'Viking FK', 'Viktoria Köln', 'Vitesse', 'Vålerenga', 'WSG Tirol', 'Wanderers', 'Wehen Wiesbaden', 'Willem', 'Without Club', 'Örebro SK']
#
# COMMUNITY 3
# Number of clubs: 58
# ['AC Fiorentina', 'AC Milan', 'AC Monza', 'AC Parma', 'AC Venezia 1907', 'AS Roma', 'Ascoli', 'Atalanta', 'Atlético Celaya', 'Benevento', 'Brescia', 'CSKA Moscow', 'CSKA Sofia', 'Cagliari', 'Campobasso', 'Career break', 'Catanzaro', 'Cavese', 'Chievo Verona', 'Cittadella', 'Club Bruges', 'Cremonese', 'Crotone', 'Delfino Pescara 1936', 'Empoli', 'FC Honka', 'FC Internazionale', 'FK Partizani', 'Fermana', 'GE Juventus-SC', 'Genoa', 'Hellas Verona', 'Internacional', 'Juve Next Gen', 'Kairat Moscow', 'Lazio', 'Lecce', 'NK Domzale', 'NS Mura', 'Napoli', 'Paganese', 'Pordenone', 'Rakow', 'River Plate', 'SPAL', 'Salernitana', 'Sampdoria', 'Sassuolo', 'Shakhtar', 'Slask Wroclaw', 'Spezia', 'Sport Recife', 'Tekstilshchik', 'Torino', 'Union Española', 'Valmiera', 'Verona', 'Wolfsberger AC']
#
# COMMUNITY 4
# Number of clubs: 140
# ['AEL Limassol', 'AIK', 'AO Egaleo', 'Académica Coimbra', 'Al-Faisaly FC', 'Al-Gharafa SC', 'Al-Ittihad', 'Al-Nasr', 'Al-Raed', 'Al-Wahda FC', 'Al-Wakrah SC', 'Alanyaspor', 'Alavés', 'Albirex Niigata', 'Amora FC', 'América-MG', 'Anápolis-GO', 'Aris Limassol', 'Arouca', 'Atlético-GO', 'Azuriz FC', 'B SAD', 'BJ Guoan', 'Ban', 'Belenenses', 'Benfica', 'Boavista', 'Bordeaux', 'Botev Plovdiv', 'Braga', 'CA Felgueiras', 'CD Feirense', 'CD Olimpia', 'CD Santa Clara', 'CD Tondela', 'CD Trofense', 'CF Estrela', 'CP El Ejido', 'CS Marítimo', 'CSA', 'Caracas FC', 'Casa Pia', 'Ceará SC', 'Celtic', 'Chaves', 'Coimbra-MG', 'Cray Wanderers FC', 'Cruzeiro', 'Dnipro', 'Dunajska Streda', 'EA Guingamp', 'EC Bahia', 'Estoril', 'Eulália Vizela', 'FC Andorra', 'FC Ashdod', 'FC Famalicão', 'FC Ingolstadt', 'FC Paços de Ferreira', 'FC Porto', 'FC Tirsense', 'FC Tokyo', 'FC Vizela', 'FK Krasnodar', 'FK TSC', 'Famalicão', 'Farense', 'Ferro', 'Gil Vicente', 'Goiás EC', 'Grecia', 'Grêmio', 'GuaZ FC', 'Guimarães', 'H. Petah Tikva', 'Hatta Club', 'Horoya AC', 'Jeonbuk Hyundai', 'KRC Genk', 'Kashima Antlers', 'LASK', 'Leiria', 'Leixões', 'León', 'Ludogorets', 'Mafra', 'Mazatlán FC', 'Metalist', 'Monarcas Morelia', 'Moreirense', 'Nagoya Grampus', 'Neftchi', 'Náutico', 'Oliv. Hospital', 'Orlando', 'PAE Chania', 'Palmeiras', 'Paysandu SC', 'Paços F.', 'Pedras Salgadas', 'Pereira', 'Petro Luanda', 'Pevidem', 'Pevidém', 'Podbrezova', 'Portimonense', 'Praiense', 'Puerto Cabello', 'Puskás AFC', 'Qarabag FK', 'R. Majadahonda', 'RFC Seraing', 'Real SC', 'Red Star', 'Rio Ave', 'Rosenborg', 'SC Covilhã', 'Salgueiro', 'San Antonio FC', 'Sanjoanense', 'Santarém', 'Servette FC', 'Setúbal', 'Slavia Prague', 'Sligo Rovers', 'Sporting', 'Stade Reims', 'São Bernardo-SP', 'SönderjyskE', 'Tokushima Vort.', 'Tokyo Verdy', 'Tsarsko Selo', 'UD Melilla', 'Union Magdalena', 'Valadares Gaia', 'Varzim', 'Vasco', 'Vianense', 'Vila Nova FC', 'Vizela']
#
# COMMUNITY 5
# Number of clubs: 143
# ['AC Pisa', 'AFC Bournemouth', 'AFC Wimbledon', 'Accrington', 'Alcorcón', 'Aldershot', 'Altay SK', 'Antalyaspor', 'Arsenal FC', 'Athletic', 'Barnsley', 'Birmingham', 'Blackburn', 'Blackpool', 'Bodø/Glimt', 'Botafogo', 'Bra', 'Brentford', 'Brighton', 'Bristol', 'Bröndby IF', 'Burnley FC', 'Burton', 'Cardiff', 'Cavalry FC', 'Charlton', 'Cheltenham', 'Colchester', 'Como', 'Concord Rangers', 'Coventry', 'Crawley Town', 'Crystal Palace', 'Derby', 'Dorking', 'Dundee United', 'Düsseldorf', 'ESTAC Troyes', 'East Preston', 'Everton', 'FC Basel', 'FC Rapid', 'FC Winterthur', 'FC Zürich', 'FSV Zwickau', 'Fenerbahce', 'Fleetwood', 'Forest Green', 'Fulham', 'Grimsby', 'Guanacasteca', 'HB Köge', 'Hampton & Rich.', 'Harrogate Town', 'Hatayspor', 'Heart of Midl.', 'Herediano', 'Hibernian FC', 'Huddersfield', 'Hull', 'Ipswich', 'KV Kortrijk', 'KVC Westerlo', 'Kilmarnock FC', 'LD Alajuelense', 'Le Puy Foot', 'Leeds', 'Leicester City', 'Lewes', 'Leyton Orient', 'Libertad', 'Lincoln City', 'Liverpool FC', 'Livingston FC', 'Lommel SK', 'Luton', 'MK Dons', 'Maidenhead Utd.', 'Maidstone', 'Manchester City', 'Manchester United', 'Marseille', 'Melbourne', 'Middlesbrough', 'Millwall', 'Morecambe', 'Motherwell FC', 'New York RB', 'Newcastle', 'Northampton', 'Norwich', 'Nottingham', 'Nottm Forest', 'OGC Nice', 'Olympiacos', 'Oxford United', 'Paris SG', 'Paris Saint-Germain', 'Pau FC', 'Peterborough', 'Plymouth', 'Port Vale', 'Portsmouth', 'Preston', 'QPR', 'Queens Park Rangers', 'RB Salzburg', 'RWDM', 'Reading', 'Rotherham', 'SD Amorebieta', 'SV Sandhausen', 'Salford', 'Shamrock Rovers', 'Sheff Wed', 'Shrewsbury', 'Slovan Liberec', 'Southampton FC', 'Southend', 'St. Johnstone', 'St. Mirren', "St. Pat's", 'Stockport', 'Stoke', 'Sunderland', 'Sutton Utd', 'Swansea', 'Telford Utd', 'Torquay', 'Tranmere Rovers', 'U. Católica', 'US Avranches', 'Union SG', 'Vilafranquense', 'Volos NPS', 'Vélez Sarsfield', 'West Brom', 'West Ham', 'Wigan', 'Woking', 'Wycombe', 'Y. Malatyaspor', 'Zulte Waregem']
#
# COMMUNITY 6
# Number of clubs: 76
# ['1.FSV Mainz 05', 'A. Lustenau', 'AC Ajaccio', 'AC Le Havre', 'AJ Auxerre', 'AS Monaco', 'AS Nancy', 'AS Saint-Étienne', 'Admira Wacker', 'Alianza Atl.', 'Amiens SC', 'Angers SCO', 'Austin', 'Bastia-Borgo', 'Bourg-en-Bresse', 'Brest', 'CA Talleres', 'CS Sedan', 'Caen', 'Chamois Niort', 'Châteauroux', 'Clermont', 'Cuiabá-MT', 'Dijon', 'E. Frankfurt', 'Emmen', 'Esperance', 'FC Aarau', 'FC Annecy', 'FC Hansa Rostock', 'FC Le Mans', 'FC Lorient', 'FC Metz', 'FC Nantes', 'FC Sochaux', 'FC Villefranche', 'FK Sarajevo', 'FSV Mainz 05', 'Heracles', 'Jong KAA Gent', 'LOSC Lille', 'LR Vicenza', 'Lausanne-Sport', 'Lens', 'Los Angeles', 'Lubin', 'MAS Fes', 'Maccabi Haifa', 'Minnesota', 'Montpellier', 'Moulins-Yzeure', 'New England', 'Nîmes', 'OH Leuven', 'Olym. Charleroi', 'Olymp. Lyon', 'Olympique Lyon', 'Paris FC', 'Quevilly', 'R. Strasbourg', 'RC Strasbourg Alsace', 'RSC Charleroi', 'RSCA Futures', 'Rodez AF', 'SC Bastia', 'SO Cholet', 'Shimizu S-Pulse', 'Sport. Cristal', 'Stade Briochin', 'Stade Rennais', 'Stade-Lausanne', 'Trélissac FC', 'US Orléans', 'USL Dunkerque', 'Valenciennes', 'Wydad AC']

# %%
from collections import Counter

for community_id, clubs in communities.items():
    
    league_counts = Counter(
        club_to_league.get(club, "Unknown")
        for club in clubs
    )
    
    print(f"\nCOMMUNITY {community_id}")
    print(f"Number of clubs: {len(clubs)}")
    
    print("\nLeague composition:")
    
    for league, count in league_counts.most_common():
        print(f"{league}: {count}")
# Out:
# COMMUNITY 0
# Number of clubs: 83
#
# League composition:
# Unknown: 45
# spanish_laliga: 33
# english_premier_league: 4
# italian_serieA: 1
#
# COMMUNITY 1
# Number of clubs: 102
#
# League composition:
# Unknown: 80
# russian_premier_liga: 21
# dutch_eredivisie: 1
#
# COMMUNITY 2
# Number of clubs: 172
#
# League composition:
# Unknown: 116
# german_bundesliga: 27
# dutch_eredivisie: 24
# english_premier_league: 2
# russian_premier_liga: 1
# french_ligue1: 1
# italian_serieA: 1
#
# COMMUNITY 3
# Number of clubs: 58
#
# League composition:
# Unknown: 29
# italian_serieA: 28
# russian_premier_liga: 1
#
# COMMUNITY 4
# Number of clubs: 140
#
# League composition:
# Unknown: 105
# portugese_ligaNOS: 29
# french_ligue1: 4
# russian_premier_liga: 1
# german_bundesliga: 1
#
# COMMUNITY 5
# Number of clubs: 143
#
# League composition:
# Unknown: 88
# english_premier_league: 39
# english_championship: 10
# french_ligue1: 4
# italian_serieA: 1
# german_bundesliga: 1
#
# COMMUNITY 6
# Number of clubs: 76
#
# League composition:
# Unknown: 45
# french_ligue1: 27
# german_bundesliga: 2
# dutch_eredivisie: 2

# %%
# Community 0: Spanish
# Community 1: Russian
# Community 2: German & Dutch
# Community 3: Italian
# Community 4: Portuguese
# Community 5: English
# Community 6: French
